# %% [markdown]
# ## 0. 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
# 데이터 읽기
df = pd.read_csv('data/data_drifter.csv')

# %%
# 데이터 분할
X = df[['time', 'lons', 'lats', 'uo', 'vo', 'u10', 'v10', 'next_time']]
y = df[['next_lons', 'next_lats']]

# %%
# 데이터 정규화
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# %%
# train, test 분할
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %% [markdown]
# ## 2. 모델 구성하기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(Dense(2))
model.compile(optimizer='adam', loss='mse')

# 모델 구조 확인
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10400
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 10502 (41.02 KB)
# Trainable params: 10502 (41.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. 학습 및 평가하기

# %%
# reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# 학습
model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), verbose=1)

# 평가
loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
# Out:
# Epoch 1/200
# 384/384 [==============================] - 2s 3ms/step - loss: 0.0203 - val_loss: 0.0093
# Epoch 2/200
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 3/200
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 4/200
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 5/200
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 9.3658e-04
# Epoch 6/200
# 384/384 [==============================] - 1s 2ms/step - loss: 4.5422e-04 - val_loss: 5.1090e-04
# Epoch 7/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.0217e-04 - val_loss: 4.1696e-04
# Epoch 8/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.0548e-04 - val_loss: 2.1986e-04
# Epoch 9/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7608e-04 - val_loss: 3.4266e-04
# Epoch 10/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3846e-04 - val_loss: 2.4016e-04
# Epoch 11/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1630e-04 - val_loss: 9.0530e-05
# Epoch 12/200
# 384/384 [==============================] - 1s 2ms/step - loss: 9.0810e-05 - val_loss: 9.0574e-05
# Epoch 13/200
# 384/384 [==============================] - 1s 2ms/step - loss: 7.2095e-05 - val_loss: 1.3466e-04
# Epoch 14/200
# 384/384 [==============================] - 1s 2ms/step - loss: 6.1773e-05 - val_loss: 6.1429e-05
# Epoch 15/200
# 384/384 [==============================] - 1s 2ms/step - loss: 5.8493e-05 - val_loss: 1.3469e-04
# Epoch 16/200
# 384/384 [==============================] - 1s 2ms/step - loss: 4.1914e-05 - val_loss: 2.7887e-05
# Epoch 17/200
# 384/384 [==============================] - 1s 2ms/step - loss: 4.2995e-05 - val_loss: 8.8963e-05
# Epoch 18/200
# 384/384 [==============================] - 1s 2ms/step - loss: 5.0724e-05 - val_loss: 8.0153e-05
# Epoch 19/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.2597e-05 - val_loss: 7.0075e-05
# Epoch 20/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.2568e-05 - val_loss: 7.9368e-05
# Epoch 21/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.0959e-05 - val_loss: 9.0781e-05
# Epoch 22/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.1453e-05 - val_loss: 1.7258e-05
# Epoch 23/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.9082e-05 - val_loss: 7.6394e-05
# Epoch 24/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.8488e-05 - val_loss: 4.6786e-05
# Epoch 25/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.9779e-05 - val_loss: 1.3368e-05
# Epoch 26/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4760e-05 - val_loss: 1.6037e-05
# Epoch 27/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.3701e-05 - val_loss: 1.5213e-05
# Epoch 28/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4628e-05 - val_loss: 1.5218e-05
# Epoch 29/200
# 384/384 [==============================] - 1s 2ms/step - loss: 3.0249e-05 - val_loss: 2.5807e-05
# Epoch 30/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.3418e-05 - val_loss: 4.0581e-05
# Epoch 31/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.6727e-05 - val_loss: 4.5386e-05
# Epoch 32/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.5834e-05 - val_loss: 1.3415e-05
# Epoch 33/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.2753e-05 - val_loss: 1.2582e-05
# Epoch 34/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.3833e-05 - val_loss: 2.7097e-05
# Epoch 35/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4770e-05 - val_loss: 2.1710e-05
# Epoch 36/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.7471e-05 - val_loss: 1.1835e-05
# Epoch 37/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.3681e-05 - val_loss: 2.0084e-05
# Epoch 38/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4854e-05 - val_loss: 4.0739e-05
# Epoch 39/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8357e-05 - val_loss: 3.2747e-05
# Epoch 40/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4047e-05 - val_loss: 1.1999e-05
# Epoch 41/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9545e-05 - val_loss: 1.2346e-05
# Epoch 42/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.4190e-05 - val_loss: 3.8905e-05
# Epoch 43/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.1086e-05 - val_loss: 1.9407e-05
# Epoch 44/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9708e-05 - val_loss: 1.3176e-05
# Epoch 45/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.1656e-05 - val_loss: 1.5121e-05
# Epoch 46/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.0437e-05 - val_loss: 2.0363e-05
# Epoch 47/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.0315e-05 - val_loss: 1.7601e-05
# Epoch 48/200
# 384/384 [==============================] - 1s 3ms/step - loss: 2.2358e-05 - val_loss: 2.8600e-05
# Epoch 49/200
# 384/384 [==============================] - 1s 3ms/step - loss: 2.4244e-05 - val_loss: 2.3444e-05
# Epoch 50/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6483e-05 - val_loss: 4.3115e-05
# Epoch 51/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.9608e-05 - val_loss: 1.6699e-04
# Epoch 52/200
# 384/384 [==============================] - 1s 3ms/step - loss: 2.3266e-05 - val_loss: 1.6903e-05
# Epoch 53/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7243e-05 - val_loss: 2.7106e-05
# Epoch 54/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9998e-05 - val_loss: 4.4158e-05
# Epoch 55/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7138e-05 - val_loss: 1.5371e-05
# Epoch 56/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.1126e-05 - val_loss: 2.7162e-05
# Epoch 57/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6691e-05 - val_loss: 1.1185e-05
# Epoch 58/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8590e-05 - val_loss: 4.8446e-05
# Epoch 59/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9461e-05 - val_loss: 1.7054e-05
# Epoch 60/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7545e-05 - val_loss: 2.9909e-05
# Epoch 61/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8990e-05 - val_loss: 2.6262e-05
# Epoch 62/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5741e-05 - val_loss: 9.1745e-06
# Epoch 63/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7858e-05 - val_loss: 1.8879e-05
# Epoch 64/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9762e-05 - val_loss: 1.7842e-05
# Epoch 65/200
# 384/384 [==============================] - 1s 2ms/step - loss: 2.1902e-05 - val_loss: 8.5671e-05
# Epoch 66/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5865e-05 - val_loss: 2.8927e-05
# Epoch 67/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8565e-05 - val_loss: 5.8581e-05
# Epoch 68/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8122e-05 - val_loss: 8.8038e-06
# Epoch 69/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6886e-05 - val_loss: 6.3729e-05
# Epoch 70/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7405e-05 - val_loss: 2.2235e-05
# Epoch 71/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7984e-05 - val_loss: 2.5309e-05
# Epoch 72/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7492e-05 - val_loss: 8.6656e-06
# Epoch 73/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5518e-05 - val_loss: 4.5575e-05
# Epoch 74/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8077e-05 - val_loss: 1.7512e-05
# Epoch 75/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6593e-05 - val_loss: 2.9275e-05
# Epoch 76/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4983e-05 - val_loss: 8.1820e-05
# Epoch 77/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.9708e-05 - val_loss: 8.6236e-06
# Epoch 78/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.6986e-05 - val_loss: 1.0689e-05
# Epoch 79/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.8063e-05 - val_loss: 2.8808e-05
# Epoch 80/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.3763e-05 - val_loss: 1.3059e-05
# Epoch 81/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.5329e-05 - val_loss: 8.9814e-06
# Epoch 82/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7053e-05 - val_loss: 9.3366e-05
# Epoch 83/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4319e-05 - val_loss: 2.6267e-05
# Epoch 84/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7290e-05 - val_loss: 1.4099e-05
# Epoch 85/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5052e-05 - val_loss: 4.2067e-05
# Epoch 86/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6244e-05 - val_loss: 9.1310e-05
# Epoch 87/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7302e-05 - val_loss: 1.9387e-05
# Epoch 88/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4774e-05 - val_loss: 3.7215e-05
# Epoch 89/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4339e-05 - val_loss: 1.0859e-05
# Epoch 90/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7342e-05 - val_loss: 2.4437e-05
# Epoch 91/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6095e-05 - val_loss: 1.9325e-05
# Epoch 92/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.3307e-05 - val_loss: 3.1332e-05
# Epoch 93/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7494e-05 - val_loss: 1.3026e-05
# Epoch 94/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4816e-05 - val_loss: 1.7618e-05
# Epoch 95/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4090e-05 - val_loss: 3.6767e-05
# Epoch 96/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6039e-05 - val_loss: 1.6944e-05
# Epoch 97/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.6068e-05 - val_loss: 1.3085e-05
# Epoch 98/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.7332e-05 - val_loss: 6.1661e-05
# Epoch 99/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4051e-05 - val_loss: 1.2462e-05
# Epoch 100/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3520e-05 - val_loss: 2.7711e-05
# Epoch 101/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4756e-05 - val_loss: 7.4071e-06
# Epoch 102/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5017e-05 - val_loss: 1.1206e-05
# Epoch 103/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.4869e-05 - val_loss: 4.1051e-05
# Epoch 104/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5843e-05 - val_loss: 1.6948e-05
# Epoch 105/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3508e-05 - val_loss: 9.1701e-06
# Epoch 106/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4531e-05 - val_loss: 1.0225e-05
# Epoch 107/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3224e-05 - val_loss: 1.5362e-05
# Epoch 108/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3496e-05 - val_loss: 2.2051e-05
# Epoch 109/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5352e-05 - val_loss: 1.5305e-05
# Epoch 110/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.2835e-05 - val_loss: 1.4770e-05
# Epoch 111/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4056e-05 - val_loss: 7.9234e-06
# Epoch 112/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4315e-05 - val_loss: 9.3935e-06
# Epoch 113/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5082e-05 - val_loss: 1.1323e-05
# Epoch 114/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.2398e-05 - val_loss: 8.3324e-06
# Epoch 115/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4066e-05 - val_loss: 1.3973e-05
# Epoch 116/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2866e-05 - val_loss: 4.7357e-05
# Epoch 117/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.4048e-05 - val_loss: 1.6713e-05
# Epoch 118/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4302e-05 - val_loss: 7.7207e-06
# Epoch 119/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.5024e-05 - val_loss: 1.1522e-05
# Epoch 120/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4010e-05 - val_loss: 1.1411e-05
# Epoch 121/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1941e-05 - val_loss: 9.4201e-06
# Epoch 122/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3970e-05 - val_loss: 1.2257e-05
# Epoch 123/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3235e-05 - val_loss: 2.2504e-05
# Epoch 124/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.5450e-05 - val_loss: 1.0453e-05
# Epoch 125/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.2271e-05 - val_loss: 1.2891e-05
# Epoch 126/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2600e-05 - val_loss: 1.3978e-05
# Epoch 127/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1807e-05 - val_loss: 2.2788e-05
# Epoch 128/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.4316e-05 - val_loss: 2.3945e-05
# Epoch 129/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.0792e-05 - val_loss: 7.7319e-06
# Epoch 130/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4351e-05 - val_loss: 2.4915e-05
# Epoch 131/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2386e-05 - val_loss: 1.6351e-05
# Epoch 132/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3738e-05 - val_loss: 1.8639e-05
# Epoch 133/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2205e-05 - val_loss: 1.3553e-05
# Epoch 134/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2703e-05 - val_loss: 2.0048e-05
# Epoch 135/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3554e-05 - val_loss: 4.1721e-05
# Epoch 136/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3437e-05 - val_loss: 3.2272e-05
# Epoch 137/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1852e-05 - val_loss: 8.4455e-06
# Epoch 138/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3074e-05 - val_loss: 1.3974e-05
# Epoch 139/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2606e-05 - val_loss: 3.2776e-05
# Epoch 140/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4909e-05 - val_loss: 7.3450e-06
# Epoch 141/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3180e-05 - val_loss: 9.9268e-06
# Epoch 142/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3388e-05 - val_loss: 1.2107e-05
# Epoch 143/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3605e-05 - val_loss: 1.1008e-05
# Epoch 144/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4128e-05 - val_loss: 1.2510e-05
# Epoch 145/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1015e-05 - val_loss: 1.0008e-05
# Epoch 146/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1004e-05 - val_loss: 9.1157e-06
# Epoch 147/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2184e-05 - val_loss: 6.2536e-05
# Epoch 148/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.4576e-05 - val_loss: 1.5330e-05
# Epoch 149/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1356e-05 - val_loss: 9.5768e-06
# Epoch 150/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3762e-05 - val_loss: 1.9790e-05
# Epoch 151/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2487e-05 - val_loss: 7.6315e-06
# Epoch 152/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2108e-05 - val_loss: 2.6095e-05
# Epoch 153/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1910e-05 - val_loss: 3.8035e-05
# Epoch 154/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2219e-05 - val_loss: 7.0245e-06
# Epoch 155/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3521e-05 - val_loss: 1.4834e-05
# Epoch 156/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2511e-05 - val_loss: 2.1004e-05
# Epoch 157/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3421e-05 - val_loss: 1.4371e-05
# Epoch 158/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1134e-05 - val_loss: 1.0575e-05
# Epoch 159/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0777e-05 - val_loss: 8.7913e-06
# Epoch 160/200
# 384/384 [==============================] - 1s 3ms/step - loss: 1.0429e-05 - val_loss: 1.0667e-05
# Epoch 161/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2536e-05 - val_loss: 7.5768e-06
# Epoch 162/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1848e-05 - val_loss: 1.1265e-05
# Epoch 163/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1899e-05 - val_loss: 2.1870e-05
# Epoch 164/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1737e-05 - val_loss: 1.2399e-05
# Epoch 165/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0566e-05 - val_loss: 8.4480e-06
# Epoch 166/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1947e-05 - val_loss: 1.9955e-05
# Epoch 167/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2093e-05 - val_loss: 1.9116e-05
# Epoch 168/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1272e-05 - val_loss: 1.4625e-05
# Epoch 169/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0491e-05 - val_loss: 6.8757e-06
# Epoch 170/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1607e-05 - val_loss: 2.2159e-05
# Epoch 171/200
# 384/384 [==============================] - 1s 2ms/step - loss: 9.8188e-06 - val_loss: 7.8972e-06
# Epoch 172/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1522e-05 - val_loss: 9.9739e-06
# Epoch 173/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1195e-05 - val_loss: 2.9803e-05
# Epoch 174/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1706e-05 - val_loss: 3.3713e-05
# Epoch 175/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1723e-05 - val_loss: 1.1222e-05
# Epoch 176/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1391e-05 - val_loss: 1.8465e-05
# Epoch 177/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1415e-05 - val_loss: 1.4736e-05
# Epoch 178/200
# 384/384 [==============================] - 1s 2ms/step - loss: 9.6545e-06 - val_loss: 8.3201e-06
# Epoch 179/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0628e-05 - val_loss: 2.5926e-05
# Epoch 180/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3240e-05 - val_loss: 7.9406e-06
# Epoch 181/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0785e-05 - val_loss: 1.0787e-05
# Epoch 182/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0615e-05 - val_loss: 1.1088e-05
# Epoch 183/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0155e-05 - val_loss: 1.1362e-05
# Epoch 184/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0508e-05 - val_loss: 6.2513e-06
# Epoch 185/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1532e-05 - val_loss: 1.3101e-05
# Epoch 186/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1898e-05 - val_loss: 1.9099e-05
# Epoch 187/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1570e-05 - val_loss: 1.4168e-05
# Epoch 188/200
# 384/384 [==============================] - 1s 2ms/step - loss: 9.9696e-06 - val_loss: 1.2043e-05
# Epoch 189/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1530e-05 - val_loss: 1.8750e-05
# Epoch 190/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0428e-05 - val_loss: 1.0902e-05
# Epoch 191/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1137e-05 - val_loss: 1.8918e-05
# Epoch 192/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1263e-05 - val_loss: 2.9722e-05
# Epoch 193/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1222e-05 - val_loss: 1.4165e-05
# Epoch 194/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.2085e-05 - val_loss: 8.4259e-06
# Epoch 195/200
# 384/384 [==============================] - 1s 2ms/step - loss: 9.5596e-06 - val_loss: 5.1065e-05
# Epoch 196/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0274e-05 - val_loss: 2.7430e-05
# Epoch 197/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0896e-05 - val_loss: 1.1455e-05
# Epoch 198/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0252e-05 - val_loss: 1.1019e-05
# Epoch 199/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.1184e-05 - val_loss: 8.4028e-06
# Epoch 200/200
# 384/384 [==============================] - 1s 2ms/step - loss: 1.0763e-05 - val_loss: 1.4124e-05
# Test Loss: 0.0000

# %%
# 과적합 방지하는 코드 추가

from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# 학습
model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stop])

# 평가
loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")

# %% [markdown]
# # 학습된 모델로 경로 예측하기

# %% [markdown]
# ## 0. 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

# %% [markdown]
# ## 1. 데이터 불러오기
#     ### 1-1. 초기값 가져오기

# %%
# 데이터 읽기
drifter = pd.read_csv("data/drifter_2016.csv")

# %%
# 시간 변환 함수
def convert_to_nearest_6hour(year, month, day, hour, minute):
    # 데이터 값을 정수형으로 변환
    year = int(year)
    month = int(month)
    day = int(day)
    hour = int(hour)
    minute = int(minute)

    dt = datetime(year, month, day, hour, minute)
    base_dt = datetime(2016, 1, 1, 0, 0)
    delta = dt - base_dt
    
    hours_since_base = delta.total_seconds() / 3600
    nearest_6hour = round(hours_since_base / 6) * 6

    result_time = np.datetime64(base_dt + timedelta(hours=nearest_6hour))

    return nearest_6hour, result_time

# %%
# 결과를 저장할 리스트 생성
results = []

# %%
# 각 시작 지점에 대한 처리
for index, row in drifter.iterrows():
    time, result_time = convert_to_nearest_6hour(row['Year'], row['Month'], row['Day'], row['Hour'], row['Minute'])
    next_time = time + 6

    dataset_sea = xr.open_dataset('interpolated_sea_16.nc', engine='netcdf4')
    dataset_wind = xr.open_dataset('interpolated_wind_16.nc', engine='netcdf4')
    
    # uo, vo 값을 가져옴
    uo_value = dataset_sea['uo'].sel(time=result_time, longitude=row['Longitude'], latitude=row['Latitude'], method='nearest').item()
    vo_value = dataset_sea['vo'].sel(time=result_time, longitude=row['Longitude'], latitude=row['Latitude'], method='nearest').item()

    # u10, v10 값을 가져옴
    u10_value = dataset_wind['u10'].sel(time=result_time, longitude=row['Longitude'], latitude=row['Latitude'], method='nearest').item()
    v10_value = dataset_wind['v10'].sel(time=result_time, longitude=row['Longitude'], latitude=row['Latitude'], method='nearest').item()

    # 결과 저장
    results.append({
        'time': time,
        'lons': row['Longitude'],
        'lats': row['Latitude'],
        'uo': uo_value,
        'vo': vo_value,
        'u10': u10_value,
        'v10': v10_value,
        'next_time': next_time
    })

# %%
# 리스트를 DataFrame으로 변환
result_df = pd.DataFrame(results)

# %%
result_df
# Out:
#    time        lons       lats        uo        vo       u10       v10  \
# 0  1740  127.071833  32.507367 -0.042594  0.163610 -3.698855 -5.244993
# 1  1794  126.615817  33.759317  0.111659  0.156357 -1.989050 -1.670222
# 2  1884  129.281933  34.949633 -0.039718  0.288225 -6.011956 -6.245036
# 3  1884  129.212400  34.986667 -0.040380  0.272089 -4.942860 -5.878523
# 4  4722  127.074467  32.516267  0.049979  0.304935 -2.538096  6.621501
# 5  4788  129.297233  34.921750  0.203083  0.389139  1.072325  2.255833
# 6  4824  129.398283  37.552583  0.025877  0.015028 -3.240538  1.653777
#
#    next_time
# 0       1746
# 1       1800
# 2       1890
# 3       1890
# 4       4728
# 5       4794
# 6       4830

# %% [markdown]
# ## 2. 모델로 예측하기

# %%
# 각 시작 지점에서의 100일간 예측
predict_duration = 400  # 100일 * 4 (하루에 6시간 단위로 4번 예측)

# 예측 결과를 저장할 DataFrame
predictions_df = pd.DataFrame(columns=['start_lons', 'start_lats', 'predicted_lons', 'predicted_lats', 'time'])

for index, row in result_df.iterrows():
    current_lon = row['lons']
    current_lat = row['lats']
    current_time = row['time']

    for _ in range(predict_duration):
        # 현재 위치와 시간을 기반으로 uo, vo, u10, v10 값을 가져옵니다.
        uo_value = dataset_sea['uo'].sel(time=current_time, longitude=current_lon, latitude=current_lat, method='nearest').item()
        vo_value = dataset_sea['vo'].sel(time=current_time, longitude=current_lon, latitude=current_lat, method='nearest').item()
        u10_value = dataset_wind['u10'].sel(time=current_time, longitude=current_lon, latitude=current_lat, method='nearest').item()
        v10_value = dataset_wind['v10'].sel(time=current_time, longitude=current_lon, latitude=current_lat, method='nearest').item()

        # 모델에 입력값을 넣어 다음 위치를 예측합니다.
        input_data = np.array([[uo_value, vo_value, u10_value, v10_value]])
        input_data = input_data.reshape((input_data.shape[0], input_data.shape[1], 1))
        prediction = model.predict(input_data)
        
        # 예측된 위치를 업데이트
        predicted_lon = prediction[0][0]
        predicted_lat = prediction[0][1]

        predictions_df = predictions_df.append({
            'start_lons': current_lon,
            'start_lats': current_lat,
            'predicted_lons': predicted_lon,
            'predicted_lats': predicted_lat,
            'time': current_time
        }, ignore_index=True)

        # 다음 반복을 위한 현재 위치와 시간 업데이트
        current_lon = predicted_lon
        current_lat = predicted_lat
        current_time += 6  # 6시간 뒤로 이동

print(predictions_df)
